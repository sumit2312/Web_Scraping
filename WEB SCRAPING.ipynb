# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "url = "https://boston.craigslist.org/search/sof""

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  - craigslist</title>\n\n    <meta name="description" content="boston software/qa/dba/etc  - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://boston.craigslist.org/search/sof">\n    <link rel="alternate" type="application/rss+xml" href="https://boston.craigslist.org/search/sof?format=rss" title="RSS feed for craigslist | boston software/qa/dba/etc  - craigslist">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=281764e2707bd58e05233e4b7df36df8">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=2d972697128e23b83898e73d71ad0d39">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "4";\nvar areaRegion = "MA";\nvar catAbb = "sof";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "jjj";\nvar sectionBase = "jjj";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n    <!--[if lt IE 9]>\n<script src="//www.craigslist.org/js/html5shiv.min.js?v=842da1f4e6843c73e1f537775ad18488" type="text/javascript" ></script>\n\n<script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>\n\n<![endif]-->\n<!--[if lte IE 7]>\n<script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>\n\n<![endif]-->\n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n        }\n        pagemode = pagemode === \'mobile\' ? \'mobile\' : \ ...

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
print(soup)
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
# <title>boston software/qa/dba/etc  - craigslist</title>
# <meta content="boston software/qa/dba/etc  - craigslist" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="https://boston.craigslist.org/search/sof" rel="canonical"/>
# <link href="https://boston.craigslist.org/search/sof?format=rss" rel="alternate" title="RSS feed for craigslist | boston software/qa/dba/etc  - craigslist" type="application/rss+xml"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="//www.craigslist.org/styles/cl.css?v=281764e2707bd58e05233e4b7df36df8" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/search.css?v=2d972697128e23b83898e73d71ad0d39" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
# <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "4";
# var areaRegion = "MA";
# var catAbb = "sof";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "list";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "jjj";
# var sectionBase = "jjj";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
# <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=842da1f4e6843c73e1f537775ad18488" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
# </meta></head>
# <body class="search has-map">
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
# <section class="page-container" id="page-top">
# <div class="bglogo"></div>
# <header class="global-header wide">
# <a class="header-logo" href="/" name="logoLink">CL</a>
# <nav class="breadcrumbs-container">
# <form action="/search/sof" class="breadcrumbs-form" data-action="/search/###/sof" id="breadcrumbform" method="get">
# <ul class="breadcrumbs ">
# <li class="crumb area">
# <span class="no-js">
# <a href="/">boston</a>
# </span>
# <select class="js-only" id="areaAbb" name="areaAbb">
# <option value="boston">boston</option>
# <option value="albany">albany, NY</option>
# <option value="capecod">cape cod</option>
# <option value="catskills">catskills</option>
# <option value="cnj">central NJ</option>
# <option value="newlondon">eastern CT</option>
# <option value="glensfalls">glens falls</option>
# <option value="hartford">hartford</option>
# <option value="hudsonvalley">hudson valley</option>
# <option value="jerseyshore">jersey shore</option>
# <option value="longisland">long island</option>
# <option value="maine">maine</option>
# <option value="nh">new hampshire</option>
# <option value="newhaven">new haven</option>
# <option value="newyork">new york</option>
# <option value="newjersey">north jersey</option>
# <option value="nwct">northwest CT</option>
# <option value="oneonta">oneonta</option>
# <option value="plattsburgh">plattsburgh</option>
# <option value="poconos">poconos</option>
# <option value="providence">rhode island</option>
# <option value="sherbrooke">sherbrooke</option>
# <option value="southcoast">south coast</option>
# <option value="utica">utica</option>
# <option value="vermont">vermont</option>
# <option value="westernmass">western mass</option>
# <option value="worcester">worcester</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb subarea">
# <select id="subArea" name="subArea">
# <option selected="" value="">all boston</option>
# <option value="gbs">boston/camb/brook</option>
# <option value="bmw">metro west</option>
# <option value="nos">north shore</option>
# <option value="nwb">northwest/merrimack</option>
# <option value="sob">south shore</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb section">
# <select id="catAbb" name="catAbb">
# <option value="ccc">community</option>
# <option value="eee">events</option>
# <option value="sss">for sale</option>
# <option value="ggg">gigs</option>
# <option value="hhh">housing</option>
# <option selected="" value="jjj">jobs</option>
# <option value="rrr">resumes</option>
# <option value="bbb">services</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb category">
# <select class="js-only" id="subcatAbb">
# <option value="jjj">all</option>
# <option value="ofc">admin/office</option>
# <option value="bus">business</option>
# <option value="csr">customer service</option>
# <option value="edu">education</option>
# <option value="egr">engineering</option>
# <option value="etc">etcetera</option>
# <option value="acc">finance</option>
# <option value="fbh">food/bev/hosp</option>
# <option value="lab">general labor</option>
# <option value="gov">government</option>
# <option value="hea">healthcare</option>
# <option value="hum">human resource</option>
# <option value="lgl">legal</option>
# <option value="mnu">manufacturing</option>
# <option value="mar">marketing</option>
# <option value="med">media</option>
# <option value="npo">nonprofit</option>
# <option value="rej">real estate</option>
# <option value="ret">retail/wholesale</option>
# <option value="sls">sales</option>
# <option value="spa">salon/spa/fitness</option>
# <option value="sci">science</option>
# <option value="sec">security</option>
# <option value="trd">skilled trades</option>
# <option selected="" value="sof">software</option>
# <option value="sad">systems/networking</option>
# <option value="tch">tech support</option>
# <option value="trp">transport</option>
# <option value="tfr">tv video radio</option>
# <option value="web">web design</option>
# <option value="wri">writing</option>
# </select><span class="no-js">software</span>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb no-js">
# <input type="submit" value="go"/>
# </li>
# </ul>
# </form>
# </nav>
# <div class="userlinks">
# <ul class="user-actions">
# <li class="user post">
# <a href="https://post.craigslist.org/c/bos">post</a>
# </li>
# <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>
# </ul>
# <ul class="user-favs-discards">
# <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
# </div>
# </li>
# <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="POST">
# <div class="to-banish-page">
# <input class="lastLink" name="lastLink" type="hidden" value="//boston.craigslist.org/search/sof"/>
# <input class="lastTitle" name="lastTitle" type="hidden" value="boston software/qa/dba/etc  - craigslist"/>
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count">0</span>
# <span class="discards-label"> hidden</span>
# </a>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </header>
# <header class="global-header narrow">
# <a class="header-logo" href="/">CL</a>
# <nav class="breadcrumbs-container">
# <ul class="breadcrumbs">
#
#
# boston            &gt;
#
# software/qa/dba/etc
#
# </ul>
# </nav>
# <span class="linklike show-wide-header">...</span>
# </header>
# <form action="/search/sof" class="search-form" id="searchform">
# <div class="querybox">
# <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search software/qa/dba/etc" type="text" value=""/>
# <button class="searchbtn" type="submit">
# <span aria-hidden="true" class="icon icon-search"></span>
# <span class="screen-reader-text">press to search craigslist</span>
# </button>
# <div class="savealert">
# <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fboston%252Ecraigslist%252Eorg%252Fsearch%252Fsof" title="save this search">save search</a>
# </div>
# </div>
# <div class="search-options-container">
# <h2 class="search-options-header linklike">
# <div aria-hidden="true" class="icon icon-toggle-gear"></div>
#         options<span class="options-close">close</span>
# </h2>
# <input id="excats" name="excats" type="hidden"/>
# <div class="search-options">
# <div class="searchgroup categories">
# <div class="cattitle">
# <a class="reset" href="/search/sof" title="clear all search parameters">software/qa/dba/etc</a>
# </div>
# </div>
# <input name="userid" type="hidden" value="">
# <div class="searchgroup">
# <ul>
# <li>
# <label class="srchType">
# <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#        </label>
# </li>
# <li>
# <label class="hasPic">
# <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#        </label>
# </li>
# <li>
# <label class="postedToday">
# <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#        </label>
# </li>
# <li>
# <label class="bundleDuplicates">
# <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#        </label>
# </li>
# <li>
# <label class="searchNearby">
# <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#        </label>
# </li>
# </ul>
# <ul class="js-only nearbyAreas ">
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="59">
#                             albany, NY <small>(alb)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="248">
#                             binghamton, NY <small>(bgm)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="239">
#                             cape cod / islands <small>(cap)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="451">
#                             catskills <small>(cat)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="349">
#                             central NJ <small>(cnj)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_31" name="nearbyArea" type="checkbox" value="481">
#                             cornwall, ON <small>(ycc)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="281">
#                             eastern CT <small>(nlo)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="453">
#                             elmira-corning <small>(elm)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="685">
#                             finger lakes, NY <small>(fgl)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="686">
#                             glens falls, NY <small>(gfl)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="44">
#                             hartford, CT <small>(htf)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="249"/>
#                             hudson valley, NY <small>(hud)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_35" name="nearbyArea" type="checkbox" value="201"/>
#                             ithaca, NY <small>(ith)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="561"/>
#                             jersey shore <small>(jys)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_41" name="nearbyArea" type="checkbox" value="385"/>
#                             kingston, ON <small>(kng)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="167"/>
#                             lehigh valley <small>(alt)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="250"/>
#                             long island, NY <small>(isp)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="169"/>
#                             maine <small>(mne)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="49"/>
#                             montreal, QC <small>(mon)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="198"/>
#                             new hampshire <small>(nhm)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="168"/>
#                             new haven, CT <small>(hvn)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="3"/>
#                             new york city <small>(nyc)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="170"/>
#                             north jersey <small>(njy)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="354"/>
#                             northwest CT <small>(nct)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="684"/>
#                             oneonta, NY <small>(onh)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="17"/>
#                             philadelphia <small>(phi)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="338"/>
#                             plattsburgh-adirondacks <small>(plb)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="356"/>
#                             poconos <small>(poc)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_29" name="nearbyArea" type="checkbox" value="683"/>
#                             potsdam-canton-massena <small>(ptd)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_38" name="nearbyArea" type="checkbox" value="278"/>
#                             reading, PA <small>(rea)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="38"/>
#                             rhode island <small>(prv)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_26" name="nearbyArea" type="checkbox" value="276"/>
#                             scranton / wilkes-barre <small>(avp)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="390"/>
#                             sherbrooke, QC <small>(shb)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="378"/>
#                             south coast, MA <small>(sma)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="286"/>
#                             south jersey <small>(snj)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="130"/>
#                             syracuse, NY <small>(syr)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="479"/>
#                             trois-rivieres, QC <small>(trs)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="247"/>
#                             utica-rome-oneida <small>(uti)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="93"/>
#                             vermont <small>(brl)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="337"/>
#                             watertown, NY <small>(wtn)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="173"/>
#                             western massachusetts <small>(wma)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="240"/>
#                             worcester / central MA <small>(wor)</small>
# </label>
# </li>
# <li>
# <span class="nextNearbyZone linklike" data-zone="1">
#                             + show <span id="nearbyNumber">42</span> more...
#                         </span>
# </li>
# </ul>
# </div>
# <div class="searchgroup">
# <span class="searchfieldlabel">miles from zip</span>
# <input class="flatinput searchInput search_distance" inputmode="numeric" max="200" min="0" name="search_distance" placeholder="miles" size="3" type="number" value=""/>
# <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
# <span class="icon icon-locate"></span>
# </div>
# <div class="searchgroup"><label class="is_internship">
# <input class="autosubmit" name="is_internship" type="checkbox" value="1">
#     internship
# </input></label><br/>
# <label class="is_nonprofit">
# <input class="autosubmit" name="is_nonprofit" type="checkbox" value="1"/>
#     non-profit
# </label><br/>
# <label class="is_telecommuting">
# <input class="autosubmit" name="is_telecommuting" type="checkbox" value="1"/>
#     telecommute
# </label><br/>
# </div><div class="searchgroup"><div class="search-attribute " data-attr="employment_type">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> employment type
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_1" name="employment_type" type="checkbox" value="1"/>
#                     full-time
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_2" name="employment_type" type="checkbox" value="2"/>
#                     part-time
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_3" name="employment_type" type="checkbox" value="3"/>
#                     contract
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_4" name="employment_type" type="checkbox" value="4"/>
#                     employee's choice
#                 </label>
# </li>
# </ul>
# </div>
# </div>
# <div class="searchgroup resetsearch">
# <a class="reset linklike" href="/search/sof" title="clear all search parameters">reset</a>
# <button class="searchlink linklike" type="submit">update search</button>
# </div>
# </input></div>
# </div>
# <div class="search-legend">
# <div class="search-view js-only">
# <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
# <ul class="dropdown-list">
# <li class="dropdown-item mode sel">
# <button data-selection="list" id="listview" title="show results in a list">
# <span class="view-list icon"></span>list
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
# <span class="view-thumb icon"></span>thumb
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
# <span class="view-gallery icon"></span>gallery
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="map" id="mapview" title="show results on a map">
# <span class="view-map icon"></span>map
#                     </button>
# <span class="toggle-arrow"></span>
# </li>
# </ul>
# </div>
# </div>
# <div class="search-sort">
# <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort " data-default-sort="date" role="toolbar">
# <ul class="dropdown-list">
# <li aria-selected="true" class="dropdown-item mode sel">
# <a data-selection="date" href="/search/sof?sort=date&amp;" title="show newest matches first">newest <span class="toggle-arrow"></span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="paginator buttongroup firstpage lastpage">
# <span class="resulttotal">
# <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/search/sof" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/search/sof" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">62</span>
# </span>
#             /
#             <span class="totalcount">62</span>
# </span>
# <a class="button next" href="" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <div class="content" id="sortable-results">
# <section class="favlistsection">
# <section class="favlistinfo">
# </section>
# <section class="banishlistinfo">
# </section>
# </section>
# <div class="open-map-view-button">
# <span>see in map view</span>
# </div>
# <div data-arealat="42.358299" data-arealon="-71.060303" id="mapcontainer">
# <div id="noresult-overlay"></div>
# <div id="noresult-text">
# <span class="message">No mappable items found</span>
# </div>
# <div class="loading" id="map">
# <div class="close-full-screen-map-mode-button">close fullscreen</div>
# <div class="close-map-view-button">close map</div>
# </div>
# </div>
# <ul class="rows">
# <li class="result-row" data-pid="6886187941">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6886187941.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 19:16" title="Fri 10 May 07:16:27 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6886187941" href="https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6886187941.html">Systems Engineer</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6886187941">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6886093658">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-python/6886093658.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 17:11" title="Fri 10 May 05:11:29 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6886093658" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-python/6886093658.html">Software Engineer - Python</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6886093658">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6886055103">
# <a class="result-image gallery" data-ids="1:00x0x_cjOdvPbnPmj,1:00F0F_jevDjJyYyiY,1:00U0U_jxYnqW9zuQ8" href="https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6886055103.html">
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 16:25" title="Fri 10 May 04:25:49 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6886055103" href="https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6886055103.html">Minecraft, Roblox, &amp; Coding Camp Program Lead</a>
# <span class="result-meta">
# <span class="result-hood"> (Manchester-By-The-Sea)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6886055103">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885987835">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6885987835.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 15:11" title="Fri 10 May 03:11:29 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885987835" href="https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6885987835.html">Data Governance Manager</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6885987835">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885987794">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-mobile-engineer/6885987794.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 15:11" title="Fri 10 May 03:11:26 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885987794" href="https://boston.craigslist.org/gbs/sof/d/boston-mobile-engineer/6885987794.html">Mobile Engineer</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6885987794">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885987745">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-senior-software-big-data/6885987745.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 15:11" title="Fri 10 May 03:11:24 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885987745" href="https://boston.craigslist.org/gbs/sof/d/boston-senior-software-big-data/6885987745.html">Senior Software Big Data/Platform Engineer</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6885987745">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885987698">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-senior-net-developer/6885987698.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 15:11" title="Fri 10 May 03:11:21 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885987698" href="https://boston.craigslist.org/gbs/sof/d/boston-senior-net-developer/6885987698.html">Senior .NET Developer</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6885987698">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885914203">
# <a class="result-image gallery" data-ids="1:01010_j0LkxOuyPWB" href="https://boston.craigslist.org/gbs/sof/d/brookline-boston-job-fair-interviews-on/6885914203.html">
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 13:56" title="Fri 10 May 01:56:46 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885914203" href="https://boston.craigslist.org/gbs/sof/d/brookline-boston-job-fair-interviews-on/6885914203.html">►►► Boston Job Fair!! Interviews on Tue, May 14 @ 11am</a>
# <span class="result-meta">
# <span class="result-hood"> (Brookline)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6885914203">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885873440">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-project-manager-software/6885873440.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 13:16" title="Fri 10 May 01:16:22 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885873440" href="https://boston.craigslist.org/gbs/sof/d/boston-project-manager-software/6885873440.html">Project Manager (Software Implementations)</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6885873440">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885873392">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-implementation-engineer/6885873392.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 13:16" title="Fri 10 May 01:16:19 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885873392" href="https://boston.craigslist.org/gbs/sof/d/boston-implementation-engineer/6885873392.html">Implementation Engineer</a>
# <span class="result-meta">
# <span class="result-hood"> (Boston)</span>
# <span class="result-tags">
#                     img
#                     <span class="maptag" data-pid="6885873392">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6885873334">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-senior-react-engineer/6885873334.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-05-10 13:16" title="Fri 10 May 01:16:17 PM">May 10</time>
# <a class="result-title hdrlnk" data-id="6885873334" href="https://boston.craigslist.org/gbs/sof/d/boston-senior
# Project Manager (Software Implementations)
# Implementation Engineer
# Senior React Engineer
# Ruby on Rails Developer
# We need your Data Engineering expertise!  Unlimited Vacation
# Product Manager
# Solutions Architect - Customer Engagement Offering
# Electronic Operations Specialist
# Senior Business Systems Analyst
# IT Systems Intern
# Information Security Analyst
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Apprentice Entrepreneur
# Junior UX and Visual Designer
# Software Engineer- Dev Ops
# Lead Full Stack Developer - Travel App
# DevOps Engineer
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# Software Development Engineer I
# IT Specialist (Data Management )
# Data Analyst - Live in PARADISE (Relo available)
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Junior Software Developer
# Lead Development Director at Hanareta (Tokyo Travel Startup)
# QA Technician
# Technology and Data Coordinator
# Clinical Content Developer
# Software Engineer - Test Automation
# Vista Implementation Specialist
# Senior Solutions Engineer
# IT Systems Implementation and Support Intern
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Junior Java Developer | Entry-level Java / J2EE or JEE Developer
# Experienced Full Stack Developer - Improving Patient Outcomes!!
# Implementer for Software Company
# Part time Accts. Receivable Reconciliation and Problem Solver
# Solutions Architect (.NET Developer)
# Senior Project Manager for Software Company
# Business Systems Analyst
# Product Owner
# Sr. Software Developer (Java & Oracle)
# Draftsman for Scaffold Projects
# Senior Software Engineer
# Software Development Engineer I
# IT Solutions Consultant
# Entry Level Software Tester
# Seeking Perl & Search engine expert
# C# .Net Developer INTERN
# Summer DevOps Internship
# Medical Equipment Inspection, Troubleshooting and Basic Repair
# Database Architect
# Web Site in conjunction w/ film showcase
# Business Analyst - UCONN

# %%
adresses = soup.find_all("span",{"class":"result-hood"})

# %%
for adress in adresses:
    print(adress.text)
# Out:
#  (Boston)
#  (Boston)
#  (Manchester-By-The-Sea)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Brookline)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Burlington, MA)
#  (Medford)
#  (Boston)
#  (Peabody)
#  (Medford)
#  (Cambridge, MA)
#  (Cambridge)
#  (Cambridge, MA)
#  (BOXBOROUGH)
#  (Cambridge MA)
#  (Waltham, MA)
#  (Cambridge, MA)
#  (Jupiter)
#  (Norwood)
#  (Boston)
#  (Boston)
#  (Newton Massachusetts)
#  (Natick MA area)
#  (Newton)
#  (Boston)
#  (Boston - free parking and on Red Line)
#  (Natick, MA area)
#  (Billerica, MA)
#  (Quincy, MA)
#  (Walham)
#  (Walham)
#  (Back Bay)
#  (Medford/Malden/Somerville)
#  (Boston)
#  (Waltham, MA)
#  (Peabody, MA)
#  (Nahsua NH)
#  (Gramercy)
#  (Newburyport)

# %%
jobs = soup.find_all('p',{"class":"result-info"})

# %%
for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time',{'class':'result-date'}).text
    link = job.find('a',{'class':'result-title'}).get('href')
    job_response = requests.get(link)
    job_data = job_response.text
    job_soup = BeautifulSoup(job_data, 'html.parser')
    job_description = job_soup.find('section',{'id':'postingbody'}).text
    job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
    job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
    print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
# Out:
# Job Title: Systems Engineer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6886187941.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Systems Engineer (Boston, MA)                   compensation: Multiple Roles ? $90K-140KOne of Boston?s most disruptive technology firms that is recreating the internet as we know it, is currently seeking multiple Systems Engineers to work in C++ along with Rust. YOUR CAREER GOALSContribute to the mission of changing the way the internet is used and delivered by architecting, developing, implementing, and supporting applications that utilize millimeter wave and/or other RF technologies. Building on your experience, you will also assist in providing team and technical supervision while driving project delivery.YOUR AMAZING QUALITIESYou are a developer with a BS or MS in Software, Computer, or Electrical engineering or equivalent discipline/experience and are comfortable developing in C++. Experience in Python and/or C are also good to have. You have at least four years of experience within a product based company, but equivalent experience will be considered. Since much of the technology runs on Linux the ideal candidate should have familiarity there to.C++LinuxRust4 years of expAnd if you've got knowledge or experience in:11a/b/g/n/ac standards and protocolsUnderstanding of millimeter wave and/or other RF technologiesReal time development and debugging skillsFamiliarity of Rust or asynchronous programming conceptsExperience building distributed systemsExperience with technical product customer issues and collaboration with customer support teams...those are certainly pluses!You must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:Premium Medical, Dental, and vision coverage with no employee contribution required12 weeks paid parental leaveCatered lunchesGreat office perks, including a free in-building gym, dry cleaning services, and a fully stocked kitchenCompany fun through social events & partiesCareer development & advancement opportunitiesGenerous PTOFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Software Engineer - Python
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-python/6886093658.html
#
# compensation: US$70000 - US$150000 per year
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior Developer - Boston, MA - $100K-$140K A fast-growing SaaS product firm within the healthcare industry is currently seeking a Senior Software Engineer. This is an opportunity to partner up with a team of entrepreneurs who have been together for years and are looking to add more great engineers to meet customer demand. This team is looking for a friendly, communicative engineer with solid Python backend engineering skills and a deep understanding of what it takes to build ambitious and innovative professional software from both a code quality and architectural design perspective.  What you will be working on:Modern, developer-driven tech stack: Python/Postgres/Flask/ReactDevelop engineering solutions to product requirements and specificationsIntegrate next-generation software within client environments (hospitals and doctor's offices)Collaborate with team members to create and extend architectures which will support major new product featuresReview team member?s code and recommend improvementsExperience:3+ years of developing major software components in PythonProven ability to independently conceive and develop innovative architectures through to completionWork as a member of a development team delivering complex, modular productsUnderstanding of web application architectures and frameworks, especially MVCSaaS B2B product domain experience is a plusComputer Science or equivalent degree (BS or MS) desired but not requiredWhat?s in it for you?Competitive base salary and bonusFast paced and agile environmentUnlimited vacationCasual dressHealth, dental, and 401kFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Minecraft, Roblox, & Coding Camp Program Lead
# Location: Manchester-By-The-Sea
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6886055103.html
#
# compensation: $662.00 per week
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Do you love to code?
#
# Are you great at teaching?
#
# Do you want to make a difference in kids' lives?
#
# If so - we want to talk to you!
#
# We are looking for an experienced coder who wants to teach kids to code in our summer camp! This person is passionate about coding and loves to work with kids. You don't need to be a game developer - our curriculum will teach that. But you need to know how to THINK about coding.
#
# To be considered for this position, please apply here: https://jobs-drobotscompany.icims.com/jobs/1388/minecraft%2c-roblox%2c-%26-coding-camp-program-lead---summer-camp-jobs-2019-%28northern-ma---manchester-%26-concord%29/job
#
# Technology Experience:
#
# Ideal applicants would demonstrate proficiency in two or more of the following areas:
#
# 2D or 3D Video Game Design • Mobile App Development for iPhone, iPad & Android • Programming in Java, Lua, Unity, Python, or C related languages • Game Modding • Character Modeling • Robotics building and programming • Web Design and Digital Photography • Artificial Intelligence or Machine • Digital Video Editing • Cyber Security or Cryptography • Augmented Reality
#
# The Program Lead Role
#
# The Program Leader serves alongside the Site Leader as a Drobots ambassador, a primary onsite liaison, and the additional communicator and “customer care” relationship manager between our company and the school’s director of summer camp programs. In addition to providing direct instruction to campers, the Program Leader is responsible for managing the staff, curriculum, materials, inventory and daily operations of Drobots’ Technology Camps at our partnered schools in your area. This role also includes, but is not limited to the supervision, responsibility, and communication of and with all Drobots instructors, attending campers and families, oversight of Drobots programs, and the overall safety, positivity and educational delivery of the company’s programs.
#
#
#
# Why This Role Is Essential
#
# Drobots is a third-party and turnkey provider of technology and STEM-based summer camp programs for schools and organizations (“schools”) across the country. Moreover, Drobots is contracted to provide complementary programming for schools that already have an existing camp model. In other words we are both the school’s partner and the visiting guest, fulfilling the majority of technology programs offered campus throughout the duration of the summer. Therefore, the Program Leader plays a vital and important role, one which is necessary to maintain strong relationships and quality assurance.
#
#
#
# Who You Will Report To
#
# The Program Leader reports to the talent and customer support teams at Drobots Headquarters in addition to the Drobots Camp Site Leader, when you work on location where a Site Leader is present.
#
#
#
# Primary Responsibility
#
# In addition to providing direct instruction to campers, the Program Leader is also the on-location, day-to-day “last-word leader and final decision maker” for Drobots’ Technology Camps. This key member of the team oversees and is responsible for: the company’s core values, the enjoyment and positive energy of all camp programming, the Drobots personnel, the integrity and implementation of the curriculum, and and above all - the safety of all campers.
#
#
#
# Training and Pre-Camp Responsibility
#
# Attend a mandatory weekend training (June 15), conducted at the geographical and school location (TBA).
# Attend 2-3 weekday remote webinar trainings (May/June)
# Complete and fulfill any company rules and regulations and curriculum-related online trainings
#
#
# Additional Tasks Include
#
# Attend and participate in company training(s) (possible travel involved) and help implement learned concepts at regional training with local staff.
# Proactive communication with Headquarters and school camp directors.
# Maintaining positive communication and relationships with the on-location Drobots staff and points of contact; parent communication; medical and emergency procedures manager.
# This position is expected to spend the majority of their time instructing campers along with the additional leadership responsibilities outlined.
# Responsibilities
# Job Type:
#
# Seasonal (Full Time) Summer Camp Jobs
#
#
#
#
# ---
# Job Title: Data Governance Manager
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6885987835.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Data Governance Manager(Boston/Lynn, MA) compensation: $170-200K plus Bonus The Nation?s largest and oldest mutual bank is currently seeking a Data Governance Manager. This individual will be the day to day leader and governor of all of this bank?s data across every business unit from lending to trading to retail and everything in-between! This is a tremendously high profile position ? interacting directly with the banks CTO and President. YOUR CAREER GOALSLead this whole bank?s data compliance initiative. You enjoy leadership and responsibility. You are a self-assured leader capable of ensuring compliance to established governance. You have the desire and ability to consider data governance proposals holistically for both impact and efficiently.YOUR AMAZING QUALITIESYou have demonstrated experience leading a data governance team, overseeing enterprise data stewardship and ensuring regulatory compliance. You are able to inspire action and growth for a team of data governance professionals. You have experience with goal-setting and team coaching to lead professional development for assigned staff. You have the following skills and experience:Strong analysis skillsExcellent written and verbal communication skillsRead proficiency with VBA3-5 years leading organizational data compliance in a PII, HIPPA, or PCI environment3+ years RDBMS experience including SQL language and entity relationship modeling3+ years financial services experienceYou must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:A comprehensive health & medical benefits packageGenerous PTO401(k) planGreat office perks, including a free in-building gym, dry cleaning services, and a fully stocked kitchenCompany fun through social events & partiesCareer development & advancement opportunitiesAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Mobile Engineer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-mobile-engineer/6885987794.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Mobile Developer (Boston, MA)                             compensation: $140KA Boston based technology firm that specializes in geospatial insights and is a leader in location technology and intelligence, seeks a strong Mobile Engineer. YOUR CAREER GOALSContribute to the mission of continuing this firm?s history of providing accurate and efficient technology to their customer base by architecting, developing, implementing, and supporting iOS and Android mobile applications. This is not a run-of-the mill app shop. This firm builds technology that provides app builders new and enhanced location capabilities and develops them in easy to integrate SDK?s and libraries.YOUR AMAZING QUALITIESYou're passionate about mobile interface design and development. You determine operational feasibility in discussions with DevOps by evaluating impact of installations and long term operations. You interact with software architects, principal software engineers and other technical leaders to understand performance requirements and recommend implementations to meet or exceed requirements. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least three years of professional experience in the full lifecycle development of iOS and Android mobile applications using:iOSAndroid (ARR) distribution process through MavenSwift and basic knowledge of CocoaPodsJava, C, C++, and Objective-CXCodeMultithreaded Software Architecture and DesignYou must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:A comprehensive health & medical benefits packageGenerous PTO (3 weeks!)401(k) plan (100% company match of up to 10% of pay)Company fun through social events & partiesLife InsuranceOccasional work from homeFSACareer development & advancement opportunitiesFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Senior Software Big Data/Platform Engineer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-big-data/6885987745.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Big Data/Platform Engineer (Boston, MA)                 $160K-180K        A Boston area software company that is considered one the most respected leaders in the healthcare industry, seeks to hire a Big Data/Platform Engineer!YOUR CAREER GOALSContribute to the mission of changing the way big data is communicated and delivered by developing, implementing, and supporting initiatives within this newly formed Platform team. Building on your experience, you will also assist in providing team and technical supervision while driving project delivery.YOUR AMAZING QUALITIESYou're passionate about creating and maintaining robust internal tools and working on a team. You recognize process or programming inefficiencies and can recommend improvements in a heartbeat. You drive to improve your craft and processes and teach others what you have learned. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least eight years of professional experience using:Node.js, Java, Perl or PythonKnowledge of Spark, HBASE and other emerging data technologies Significant Experience with Hadoop, Kafka, Cassandra, and ElasticSearchFamiliarity with Unix/Linux, Big Data, SQL, NoSQLExperience deploying or managing applications in an AWS or private cloud environmentYou must also be able to thrive in a fast-paced, deadline-driven environment.  Excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:A comprehensive health & medical benefits packageGenerous PTO (Paid Holidays plus 20 PTO days)401(k) planGreat office perksBonusEquityAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Senior .NET Developer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-net-developer/6885987698.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior Software Developer (C#)  - Cambridge, MA             $140K                                      The nation's leading educational travel firm seeks to hire a full-time .NET Developer to join its team just steps away from the Lechmere T stop in Cambridge! This organization is known for its amazing employee culture and brand new state of the art office space. Sick of working for tech startups and product firms that demand 50+ hours a week as a C# developer? This organization prides itself on work-life balance while also providing developers with a competitive pay scale and the commitment to new technologies that the top engineers in the area expect and deserve! YOUR CARRER GOALSContribute to the mission of changing the way student travel and educational tours are provided by architecting, developing, implementing, and supporting .NET applications. Building on your experience, you will also assist in providing team and technical supervision while driving project delivery.YOUR AMAZING QUALITIESYou're passionate about .NET design and development. You recognize process or programming inefficiencies and can recommend improvements in a heartbeat. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least five years of professional experience in the full lifecycle development of .NET applications using:C#/MVCExperience in an agile team environmentRestful API?sFull stack development experienceStrong background in TDD/BDD frameworksStrong SQL experienceAnd if you've got knowledge or experience in:HTML5CSS3React ...those are certainly pluses!You must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:A comprehensive health & medical benefits packageGenerous PTO 401(k) planGreat office perks, including a free in-building gym, bar/restaurant, dry cleaning services, and more!Company fun through social events & partiesCareer development & advancement opportunitiesAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: ►►► Boston Job Fair!! Interviews on Tue, May 14 @ 11am
# Location: Brookline
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/brookline-boston-job-fair-interviews-on/6885914203.html
#
# compensation: $30,000 - 120,000
#
# employment type: employee's choice
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# AVAILABLE JOBS IN SALES, RETAIL, ADMIN, CUSTOMER SERVICE, ACCOUNTING, BANKING, FINANCIAL, INFORMATION TECHNOLOGY, HEALTHCARE, LAW ENFORCEMENT, TRANSPORTATION & MORE!  Register Now
# WHEN:
# Tuesday, May 14, 2019
# 11:00 AM - 2:00 PM
#
# WHERE:
# The Inn at Brookline
# 1200 Beacon St.
# Brookline, MA 02446
#
# Managers will be conducting interviews and hiring on the spot!
#
# ***YOU MUST PRE-REGISTER TO SECURE A SPOT AT THIS EXCLUSIVE HIRING EVENT: Register Now
#
# If you have been looking for a new career or just ready to start a new job you don't want to miss this exciting hiring event. Professional Dress is required and please bring additional copies of your resume.
#  Register Now Key Words:
# Account Executive, Sales Representative, Account Manager, B2B, retail sales, furniture, sales, financial services, customer service, Business Development Manager, Sales Manager, Financial Services, Insurance, Telecommunications, Pharmaceutical, Hospital Representative, Medical, Marketing, Advertising, Healthcare, office equipment, Telecom, Information Technology, Software, Security Services, Advertising, Payroll, Sales Management, Sales Trainee, Management Trainee, At home sales, cold calling, telemarketer, telemarketing, financial advisor, insurance sales, outside sales, outside sales representative, sales executive, salesman, salesperson, sales women, marketing, Boston, MA, Mass
# ---
# Job Title: Project Manager (Software Implementations)
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-project-manager-software/6885873440.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Project Manager - Software Implementations (Boston, MA)                    compensation: $85KOne of Boston?s fast-growing FinTech companies seeks to hire a Project Manager to help their exclusive clientele navigate the implementation process of the platform.YOUR CAREER GOALSYou are ready to get excited about the product and help forge and maintain strong relationships with clients.YOUR AMAZING QUALITIESYou are passionate about getting items across the finish line, process driven, a fast learner, a strong communicator, and possess strong interpersonal skills.Experience in solution implementation, project management, and interfacing with customers, ideally within a software firmExceptional organizational skills and attention to detailsAbility to move at a quick paceExperiene using Jira or SmarsheetSelf-motivated and self-managedExperience in process improvement and documentationFamiliarity with Agile project management and implementationGreat problem solving abilitiesEffective oral and written communication skillsAnd if you've got knowledge or experience in:CAPM CertificationFinTech industry knowledgeIN EXCHANGE FOR YOUR HARD WORKWe offer you:Comprehensive Health BenefitsUnlimited VacationEquityAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Implementation Engineer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-implementation-engineer/6885873392.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Implementation Engineer (Boston)                 compensation: $90kBoston?s fastest growing FinTech seeks an Implementation Engineer to help their financial services clients leverage the power of their digital lending platform; allowing small businesses to apply for and receive loans quickly.YOUR CAREER GOALSYou have a passion for technology and want to join a team of fast-paced, process-driven engineers who will help build your skills, while offering a collaborative and exciting environment.YOUR AMAZING QUALITIESYou are a fast learner and strong communicator, with two or more years of experience under your belt in solution implementation/configuration, testing, and interfacing with customers; ideally within a software firm.YOU HAVEAt least 2 years of experience working with PostgreSQL or other relational database management systems within a similiar implemention roleAn understanding of Web Services, Web Development (Python, HTML, CSS, Javascript), and Internet ArchitectureA self-motivated and self-managed mindsetExtras:Exceptional organizational skills, meticulous attention to detail, and the ability to maintain focus in a fast-paced environmentLoan credit underwriting knowledgeTechnical writing skillsIN EXCHANGE FOR YOUR HARD WORKWe offer you:True work/life balanceUnlimited PTOStanding desks, beer Fridays, fun team outingsLatest MacBook + Apple Cinema displayFull Benefits PackageFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Senior React Engineer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-react-engineer/6885873334.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior React.JS Engineer - Boston, MA          $150K Are you passionate about leveraging the most cutting-edge web technologies out there to build beautiful, robust Uis and create intuitive user experiences? A rapidly growing technology provider for the entertainment and media industries is looking for a Senior React.JS Engineer to join its team. WHY THIS COULD BE A GREAT OPPORTUNITY FOR YOU:Join a company that's operating and growing within an industry of increasing popularity. Work on products trusted globally by tens of thousands of creative, content writing, and studio video production professionals.Drive all UI initiatives, mentor 3 existing mid-level team members and bring this firm's product into the future with all brand new development and new customization ESSENTIAL FUNCTIONS:100% front end web development responsibilities Build the UI for the company's creative workflow management solutions in ReactCollaborate with clientele, non-technical staff, and other web engineers in order to design and create new functionality that meets business needs Recognize process and code inefficiencies, and proactively recommend resolutionsQUALIFICATIONS:6+ years of professional web development experience with a focus on the UI2+ years of solid front end web development experience using React.JS, HTML5, CSS3, JavaScript, and jQueryStrong command over JavaScript libraries and frameworks like React and/or Angular Experience working within a MEAN stack environment Working knowledge of UI design concepts and principles Must have excellent written and interpersonal communication skills Must be able to plug into a small to medium-sized teamBENEFITS & PERKS SNAPSHOT:Competitive salary coupled with a comprehensive health and medical benefits packageGenerous PTO (4 weeks to start!) and flex schedule options 401(K) with company match Small, laid-back team with a *no red tape, no politics* management approachCompany-sponsored social events Fully stocked kitchen Career development and advancement opportunitiesFind Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Ruby on Rails Developer
# Location: Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-ruby-on-rails-developer/6885873286.html
#
# compensation: Up to US$140000 per year
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Ruby on Rails Developer (Boston, MA)                             compensation: $170KA fast growing and highly recognized Boston based SaaS product firm is seeking multiple full stack Ruby on Rails Engineers. Having recently moved into a state of the art facility in the financial district, this firm is consistently recognized as Boston's best places to work, prides itself on hiring A players, and is continuing to build best in class SaaS products. YOUR CAREER GOALSContribute to the mission of changing the way retail and products are communicated and delivered by architecting, developing, implementing, and supporting their consumer facing applications. Building on your experience, you will also assist in providing team and technical supervision while driving project delivery.YOUR AMAZING QUALITIESYou're passionate about software design and development. You recognize process or programming inefficiencies and can recommend improvements in a heartbeat. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least two years of professional experience in the full lifecycle of development using:RubyRailsDjangoGitRESTful API?sAnd if you've got knowledge or experience with:High-availability web applicationsRelational database designComputer Science degree...those are certainly pluses!You must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:A fully paid health & medical benefits packageGenerous PTO401(k) plan (with company match)Free catered lunches and stocked kitchenCompany fun through social events & partiesCareer development & advancement opportunitiesAnd the list continues!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: We need your Data Engineering expertise!  Unlimited Vacation
# Location: Boston
# Date: May  9
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-we-need-your-data-engineering/6885374448.html
#
# compensation: competitive in the market
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# We're hiring Data Engineers!
#
# VideoAmp’s mission is to bridge the gap between television and digital advertising with campaign measurement, planning and audience-targeting solutions that dramatically improve the performance and cost-efficiency of advertising investment. Our engineers, data scientists, designers, and media strategists are inspired by tackling one of the most challenging problems in media and marketing — bridging the divide between TV and digital media.
#
# Responsibilities
#
# As a part of VideoAmp’s platform team, you will be involved in the design, development, deployment, and testing processes for new products. Our platform provides disruptive insights and optimizes the efficacy of our client’s ad campaigns. You will be a core member of our engineering team and will have a major impact on new initiatives.  We’re mindful of how the time and space complexities of the small parts greatly affect our services at scale and we need your help to build responsive systems. You will help build, test, benchmark, and tune our distributed systems to ensure that our product is scalable, responsive, robust, cost-effective, and correct.
#
# Technology We Use
#
# Scala, Python, Java, Spark, SQL, Hive, HDFS, PostgreSQL, Redis, Druid, Kafka, Kubernetes, and other technologies to support an ETL pipeline, data warehouse, data mart, and reporting platform.
#
# Required Skills
#
# ·       2+ years of hands-on coding experience - Python or Scala preferred
#
# ·       Experience working with Spark, Hadoop, or other big data processing platform in high-volume environments
#
# ·       A solid and demonstrable understanding of ETL workflows and data warehousing
#
# ·       Experience with high-performance, low-latency, distributed systems
#
# ·       SQL fluency and an understanding of relational data models
#
# ·       Experience optimizing queries and developing stored procedures
#
#
# What you will be doing
#
# ·       Building out Spark apps to support new product development
#
# ·       Building data models to support new functionality
#
# ·       Build data pipelines to analyze, scrub, and integrate first and third party data
#
# ·       Productionalizing data science models
#
# ·       Coordinating data models with other engineering teams
#
# ·       Tuning and optimizing Spark apps to get the most out of the quickly evolving platform
#
#
#
# PERKS
#
# ·       Top compensation
#
# ·       Comprehensive health benefits
#
# ·       Meaningful equity
#
# ·       401k
#
# ·       Unlimited vacation with a stipend for travel and accommodations of $2000/year
#
# ·       Unlimited use of in-office gym
#
# ·       Unlimited access to fitness classes
#
# ·       Childcare stipend
#
# ·       Plenty of snacks and beverages
#
# ·       Corporate support for Hackathons, lunch and learns, and attending conferences
#
# ·       Personal and professional development
#
#
# ---
# Job Title: Product Manager
# Location: N/A
# Date: May  9
# Link: https://boston.craigslist.org/gbs/sof/d/woburn-product-manager/6885275761.html
#
# compensation: Competitive
#
# employment type: employee's choice
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Join our team as we create the best car search engine and most innovative tools to help consumers find the best deals on great cars. We’re turning car shopping on its head by using big data analytics and proprietary algorithms to objectively analyze, score and rank millions of cars and thousands of dealers.
#
# You’ll be a good fit if you’re a dynamic Product Manager who is a problem solver, curious and passionate about identifying opportunities to not only address the pain points of the end user but also needs the end user might not even know they have. We are looking for someone who has the creativity and humility to formulate new ideas, experiment and iterate and uses data and structured thinking to inform their approach.
#
# You will work closely with the management team to build a roadmap of ideas and differentiated solutions aimed at solving pain points for consumers and dealers and help take the company to the next level.
#
# REQUIREMENTS:
#
# * 2+ years relevant experience in product development or management for an Internet or software company
# * Strong consumer product intuition and knack for understanding if an idea will work
# * Strong analytical skills and ability to analyze data and identify key insights
# * Detail-oriented and strong organization skills
# * Bias towards action and experimentation
# * Excellent work ethic and communications skills
#
# If you’re interested, please email us a cover letter along with your resume.
#
# iSeeCars was founded by tech and business executives from TripAdvisor and SAP. Our team includes MIT, Harvard, Princeton, Yale, IIT, UPenn and Duke alums. iSeeCars has been featured extensively in the media, including The Wall Street Journal, New York Times, CNN, Consumer Reports, Forbes, Fortune, TODAY Show, USA TODAY, ABC, CBS, NBC and more.
#
# ---
# Job Title: Solutions Architect - Customer Engagement Offering
# Location: Burlington, MA
# Date: May  8
# Link: https://boston.craigslist.org/nos/sof/d/burlington-solutions-architect-customer/6884377885.html
#
# compensation: tbd
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Date Job Opened: 5-8-19
#
# Please Apply Here: https://www.ndt.com/job/solutions-architect-customer-engagement-offering
#
# Are you passionate about Customer Success?
#
# Is it time for you to take the next step in your career as a highly visible and vital member of a Customer Success team?
#
# Your Next Step Opportunity:
# •	Oversee technical aspects of deployment, integration and configuration of enterprise SaaS offering
# •	Validate product configuration options with the customer
# •	Work with the customer to map data fields from their systems to our data spec for batch process of data
# •	Work with a project manager to document the Technical solution, including specification of all aspects of deployment including data mapping, data integration, single sign on, widgets, APIs, configuration, and new feature specification
# •	Perform feature gap analysis between our existing shipping product and customer requirements
# •	Understand and document security needs
# •	Document and manage technical change requests
# •	Participate on weekly calls with core project team, IT team, and business teams
# •	Manage open items and issues and work to resolve them
#
# Your Skills/Experience:
# •	3-5 years as technical project manager and/or solutions architect for large enterprise deployments, ideally SaaS B2B enterprise applications
# •	Knowledge of SQL and understanding of how database tables relate to each other in a business sense
# •	Knowledge of system integration - Data (required), SSO, Widgets, APIs
# •	Experience working with multiple disciplines, both internally and externally – clients, engineering and product management teams.
# •	Excellent attention to detail and skills with Word, Excel, Powerpoint, MS Project, Google docs, Google Sheets
# •	Experience with Splunk, JIRA a plus
# •	Professional and credible resource for customers
# •	Foundation in Computer Science or similar and/or related technical work experience
# •	Minimal travel
#
# Reference # 8411 - Risa Kahn, Recruiting Manager
#
# Please Apply Here:  https://www.ndt.com/job/solutions-architect-customer-engagement-offering
#
# New Dimensions in Technology (NDT)
# Technical and Tech/Business Recruiting Since 1979
# ---
# Job Title: Electronic Operations Specialist
# Location: Medford
# Date: May  8
# Link: https://boston.craigslist.org/gbs/sof/d/chestnut-hill-electronic-operations/6884343053.html
#
# compensation: Commensurate with Experience.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
#
# Currently, we are searching for an enthusiastic individual to join the Century team.
#
# Job overview:
#
# Perform various balancing, reconciliation and processing duties in the Electronic Operations Department. Position involves assisting with the processing and support for operational functions with ATM card and terminal activity, Mobile services, Remote Deposit, ACH services, scanning, exception processing and maintenance review.
#
#
#
#
#
# Responsibilities:
#
#
#
#
# Monitors and/or ensures compliance with Federal and State laws and regulations; including but not limited to the Bank Secrecy Act and Anti Money Laundering, in addition to, Bank operation policies and procedures.
# Provide quality Customer Service and assistance to customers and internal customers with a timely resolution.
# Process operational functions within a timely and accurate manner.
# Perform reconcilements with accuracy, relaying any variances to management.
# Attend internal/external training sessions as required.
# Compile monthly reports for statistical purposes.
# Communicate job related information and problems to Manager/Supervisor.
# Assist in special projects as needed.
# Other duties as assigned.
#
#
#
# Qualifications:
#
#
# ...
#
# We know that finding the right internship or your first professional development job after college can be a stressful process, and there is opportunity everywhere. Like many other software companies we offer a casual office, a friendly atmosphere, and regular social events to help your first professional gig feel as relaxed as possible, but what you won’t find elsewhere is a group of people who are more passionate about what they do. We love our customers and their products, and their success is our success at every level.
#
# When we add to our team, whether it’s for a summer internship or a permanent position, we're looking for more than just a software whiz who can pound out code every day. We're looking for somebody who is as devoted to their work as we are, and who will help elevate us to the next level. We want you to find holes in our processes, introduce us to your favorite technologies, and show us what we can do better. We will never rest on our accomplishments and will always push ourselves further. Not only is it what our customers deserve, it's what makes us firebrands.
#
# A development internship at Firebrand includes:
# ●	Making real contributions to a project using multiple technologies
# ●	Participating in agile planning sessions using Jira
# ●	Interacting with various departments, which may include our architecture, support, QA, and release operations teams
# ●	Documenting useful practices and tools to share with the team
#
# Your qualifications:
# ●	Bachelor’s degree candidate
# ●	Experience with C# .Net and SQL Server
# ●	Knowledge of or experience with MVC frameworks
# ●	Excellent written and verbal communication
# ●	Knowledge of web services and protocols, REST API design, PHP, and the Symfony framework are helpful but not required
#
# You will be working out of our office in beautiful Newburyport, MA.
#
# To apply for this internship please send a cover letter and resume.
#
# No agency responses, please.
#
# Our company is committed to equal employment opportunity. We will not discriminate against employees or applicants for employment on any legally-recognized basis ["protected class"] including but not limited to: veteran status, uniform service member status, race, color, religion, sex, national origin, age, physical or mental disability, genetic information or any other protected class under federal, state or local law.
#
#
#
# ---
# Job Title: Summer DevOps Internship
# Location: N/A
# Date: May  3
# Link: https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html
#
# compensation: $15/Hr - 40 hours a week
#
# employment type: full-time
#
# internship
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Job Title: DevOps Engineer Intern
#
# Location(s): Westborough, MA
#
# QPAIR is hiring!
# QPAIR is a Cloud Operations Company and we are looking to hire summer interns.
# Interns will have an opportunity to learn from our expert DevOps engineers and a chance to work with a team of skilled DevOps engineers and software developers, assisting in building features for our CI/CD environment. The interns will be part of an Agile development team learning and following our SDLC and exposed to the latest techniques of building and deploying software into a Cloud environment.
#
# Internship will be for 3-4 months working 40 hours a week.
#
# Desired Skills:
#
# Amazon AWS
#
# Bash / Python / Boto3
#
# Jenkins
#
# AWS services and CLI
#
# Linux and Mac OS
#
# GitHub
#
# Docker
#
# QPAIR is committed to creating a diverse environment and is proud to be an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability status, age, or veteran status or any other characteristics protected by applicable law. QPAIR is committed to a culturally diverse workforce.
#
# ---
# Job Title: Medical Equipment Inspection, Troubleshooting and Basic Repair
# Location: N/A
# Date: May  4
# Link: https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html
#
# compensation: $600/week
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# BMET: Medical Device Inspection / Biomedical Equipment Analysis.
#
# Medical Equipment Dynamics (MED) is a fast growing business based in New Bedford, MA. We buy idle, decommissioned capital medical equipment to resell. The company sells new, refurbished, used and parts models. More info at https://MED.equipment
#
#
# Medical Equipment Inspection, Troubleshooting and Basic Repair
#
# Responsibilities:
#
#     Assess and perform basic testing of a wide variety of pre-owned medical equipment
#     Document various details such as data, configurations, parameters, software rev, options included, part numbers and other model specific information
#     Determine what parts and accessories should be ordered
#     Replaces parts and perform basic repairs as applicable
#     Deciphering particular variables within a specific model
#     Will assure accurate database entry with a high attention to detail
#
# Requirements:
#
#     Strong demonstrable technical troubleshooting ability
#     Basic working knowledge of electronics
#     Ability to to perform basic inspection of electronic devices
#     Able to troubleshoot and problem-solve equipment and its operation
#     Able to work independently
#     Good documentation skills
#     Computer skills
#
# Qualifications:
#
#     High school diploma, GED or equivalent. Some college or Associate's Degree preferred
#     Research driven, investigative technical skills
# ---
# Job Title: Database Architect
# Location: N/A
# Date: May  5
# Link: https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html
#
# compensation: Commensurate with experience and qualifications.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Integrated Statistics is looking for a Database Architect to work in support of the National Oceanic and Atmospheric Administration (NOAA) National Marine Fisheries Service (NMFS) Northeast Fisheries Science Center (NEFSC).  The Northeast Fisheries Science Center (NEFSC) is the research arm of NMFS in the region, planning, developing, and managing a multidisciplinary program of basic and applied research to better understand living marine resources of the Northeast Continental Shelf Ecosystem from the Gulf of Maine to Cape Hatteras, and the habitat quality essential for their existence and continued productivity, and to describe and provide to management, industry, and the public, options for the conservation and utilization of living marine resources, and for the restoration and maintenance of marine environmental quality.
#
# Tasks
# The Data Architect will assist the Data Management Systems (DMS) division, which provides IT support services to the Science Center. The Database Architect will work closely and cooperatively with federal system programmers and application developers to develop and analyze program requirements, and prepare documentation and specifications.
#
# The Database Architect will be responsible for:
#
#     Database architecture, design, and modeling.
#     Maintaining and extending database capabilities to meet business users needs and NMFS standards and best practices.
#     Data Modeling for project specific generation of database and application design documentation.
#     Documenting logical and physical data models and associated entity relationship diagrams.
#
# Qualifications
# The Database Architect must:
#
#     Demonstrate proficiency and extensive knowledge of Oracle database systems.
#     Possess demonstrated, strong programming and development skills using PL/SQL (package, procedures, functions, triggers) and batch coding skills.
#     Have experience in code migration, database change management, and data management in multiple environments and different stages of the development life cycle.
#     Possess the ability to handle multiple projects and deadlines with flexibility between tasks.
#     Be capable of working as part of a team to define and refine user requirements.
#     Have a track record of ensuring performance, security, integrity, and availability of databases.
#     Be able to support application development through integrated project work group meetings, data modeling, code reviews, and system reviews for quality and performance.
#     Demonstrate ability to work with management and developers in providing quick resolutions during critical production issues with performance related resolutions.
#     Possess expert level knowledge and experience in data modeling and database design across all phases of data modeling, from conceptualization to database optimization.
#     Provides database support by coding utilities, responding to user questions, and resolving problems.
#     Emphasize methodology, modeling, and governance while being technologically and politically neutral.
#     Be proficient in logical and physical modeling using tools such as SQLDeveloper Data Modeler, ERWin, or other data system modeling.
#     Possess a thorough understanding of data normalization.
#     Demonstrate proficient in Agile/Scrum methodology, and be familiar with project management software (e.g.,JIRA by Atlassian).
#     Be able toanalyze database performance and positively affect systems via indexing and other methods.
#     Have experience in configuration and deployment of development, test and production environments.
#     Be proficient in designing and implementing data access security via roles or other methods.
#     Be able to implement and integrate data security standards set by the NOAA/NMFS/Office of the Chief Information Officer (OCIO) and implemented by NEFSC’s DMS Division.
#     Possess advanced experience in mapping the systems and interfaces used to manage data, set standards for data management, analyze current state and conceives desired future state, and conceive projects needed to close the gap between current state and future goals.
#     Have a track record of implementing the system development life cycle; software project management approaches; and requirements, design, and test techniques.
#     Demonstrate advanced knowledge and skills necessary to develop and adhere to database standards in design and implementation, and to conceptualize and influence application and interface projects.
#     Be able to analyze database performance and positively affect systems via indexing and other tuning methods.
#
# The position is full-time, and the rate of pay is commensurate with experience and qualifications. The position is eligible for the benefits described on the Integrated Statistics website. The Database Architect is expected to work on-site in Woods Hole, MA. To apply for this position, go to https://jobs.intstats.com/JobDetails.jsp?jobListingId=187 or visit www.integratedstatistics.com, click Employment Opportunities, click the job name and click the Apply Here link.
#
# Integrated Statistics is an equal opportunity employer and will not discriminate against any employee or applicant on the basis of age, color, disability, gender, national origin, race, religion, gender identity, sexual orientation, veteran status, or any classification protected by federal, state, or local law. Consistent with its obligations under federal law, Integrated Statistics is committed to taking affirmative action to employ and advance in employment qualified women, minorities, disabled individuals, special disabled veterans, veterans of the Vietnam era, and other eligible veterans. For assistance with accessibility of applications, posters, forms, and/or documents, please email the Integrated Statistics office.
# ---
# Job Title: Web Site in conjunction w/ film showcase
# Location: N/A
# Date: May 11
# Link: https://hartford.craigslist.org/sof/d/east-hampton-web-site-in-conjunction/6886733905.html
#
# compensation: we shall negotiate it
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Hello!
# Our film company is looking to show (or hopefully seemlessly link to) our 25 minute long film from our own website (ideally) where we want to add extras like outtakes and trivia about the film. We would also like to charge just a couple bucks and give the viewer access to the film (even if actual film served from probably another film-dedicated site) for 24 or so hours (to the viewer/visitor).
#
# ***** We realize that hosting your own film on your standard web host (blue host, hostgator, etc) is difficult in terms of bandwidth and other tech factors, so we acknowledge that we will have to link/serve the film from a site dedicated to serving up & protecting video If you know how we couldlink this to a dedicated film host or another film site - and make this the smoothest transition possible with the link from our site. We realize we my have to send the viewer/visitor away from our site, but it would be ideal if we didn't have to.
#
# In short we are looking for:
#
# 1) A decent-looking web site for our film - about 3 pages - a) feature page for our 24 -hr restriced access film. b) Extra features c) Contact us page
#
# 2) A smooth way to link up to our film to a site that hosts and protects films (we realize that we will have to serve the film from another site dedicated to serving up & protecting films to avoid tech issues) If we can make this link up seemless, without visitors completely navigating away from our site forever it would be ideal.
#
# 3) Someone who can recommend a good site dedicated films (to carry out #2) - which will allow a (hopefully smooth) link to our film from our web site.
#
# If you think you can truly help us (and not give us the runaround) please respond!
#
# Thank you - we do appreciate valid responses!
# -------------------------------------------------------------------------------------------------------------------------
# PLEASE DO NOT:
#
# * Please don't schedule a call with us, and then send us an email at that call time, saying you'll call later when you have time to fit us in.
#
# * Please do not email us via additional fake burner accounts to compare notes, or for whatever weird purposes.
#
# * Please don't send us email simply saying "I can do all this easily, just give me a down payment" - without a hint of who you are or any work you've done in the past. We'd a link or some info about you and/or your work. We can't afford to pay big bucks to a smooth-talking scam/phishing artist.
#
# * Please do not send us an HTML page with a 30 second video, or a free link to a 30 second YouTube or Vimeo video, and say "See, that's how it's done. Now please pay me thousands of dollars." What we are doing is obviously a little more intricate than that - user-restricing, film-loading.
#
# * Please just don't respond and say "what is your number I will call you on my vague unpredictable schedule and tell you how this works. Just PayPal me 500 first."
#
# * Please don't tell me to call my hosting company, YouTube, Vimeo or any site with a list of technical questions. I am busy with the actual film and I've already spent hours doing this for the domain and web page hosting. I'm hoping to find someone who knows or has the time to find out this kind of information.
# ---
# Job Title: Business Analyst - UCONN
# Location: N/A
# Date: Apr 25
# Link: https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html
#
# compensation: $50-65/hr
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# UCONN has an opening for a solid Business Analyst capable of collaborating with both the functional and technical teams to work on-site at the UCONN campus in Storrs, CT.  The position is for one year.  Local candidates are preferred as they will have a face-to-face interview in Storrs.
#
# Requirements:
# •         Experience with data marts/data warehouses
# •         HR knowledge (preferable PeopleSoft but not required)
# •         Payroll Knowledge (preferable PeopleSoft but not required)
# •         Not a PeopleSoft Developer
#
# ---
